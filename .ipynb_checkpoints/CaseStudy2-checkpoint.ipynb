# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
import networkx as nx
sns.set(style="whitegrid")
pd.set_option("display.max_columns" , None)
pd.set_option('display.max_colwidth', None)
warnings.filterwarnings('ignore')

# %%
import heapq
from collections import defaultdict
import pandas as pd
import matplotlib.pylab as plt
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
#from surprise import Dataset, Reader, KNNBasic
#from surprise.model_selection import train_test_split

# %%
df = pd.read_csv('CatalogCrossSell.csv')

# %%
# checking some records
df.head()
# Out:
#    Customer Number  Clothing Division  Housewares Division  \
# 0            11569                  0                    1
# 1            13714                  0                    1
# 2            46391                  0                    1
# 3            67264                  0                    0
# 4            67363                  0                    0
#
#    Health Products Division  Automotive Division  \
# 0                         1                    1
# 1                         1                    1
# 2                         1                    1
# 3                         1                    1
# 4                         1                    0
#
#    Personal Electronics Division  Computers Division  Garden Division  \
# 0                              1                   0                0
# 1                              1                   0                1
# 2                              1                   0                1
# 3                              1                   0                1
# 4                              1                   0                1
#
#    Novelty Gift Division  Jewelry Division
# 0                      1                 0
# 1                      1                 1
# 2                      1                 1
# 3                      1                 0
# 4                      1                 0

# %%
# variables and their types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4998 entries, 0 to 4997
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer Number                4998 non-null   int64
#  1   Clothing Division              4998 non-null   int64
#  2   Housewares Division            4998 non-null   int64
#  3   Health Products Division       4998 non-null   int64
#  4   Automotive Division            4998 non-null   int64
#  5   Personal Electronics Division  4998 non-null   int64
#  6   Computers Division             4998 non-null   int64
#  7   Garden Division                4998 non-null   int64
#  8   Novelty Gift Division          4998 non-null   int64
#  9   Jewelry Division               4998 non-null   int64
# dtypes: int64(10)
# memory usage: 390.6 KB

# %%
df.astype('object').describe(include='all').loc['unique', :]
# Out:
# Clothing Division                2
# Housewares Division              2
# Automotive Division              2
# Personal Electronics Division    2
# Computers Division               2
# Garden Division                  2
# Novelty Gift Division            2
# Jewelry Division                 2
# Name: unique, dtype: int64

# %%
df.drop(['Customer Number'],axis= 1, inplace=True)

# %%
# most popular items
count = df.loc[:,:].sum()
count_df=count.to_frame().reset_index(drop=False)
count_df.columns
count_df.rename(columns={'index':'item', 0:'count'}, inplace=True)

# %%
count_df
# Out:
#                             item  count
# 0              Clothing Division    165
# 1            Housewares Division   1967
# 2       Health Products Division   4998
# 3            Automotive Division    674
# 4  Personal Electronics Division   2336
# 5             Computers Division    234
# 6                Garden Division   1360
# 7          Novelty Gift Division   1137
# 8               Jewelry Division   1784

# %%
sns.barplot('count','item',data=count_df, palette='Set2');

# %% [markdown]
# Health Products Division in all rows , we can exclude this and check support for other product.

# %%
df.drop(['Health Products Division'],axis=1, inplace=True)

# %% [markdown]
# # Association with min_support 0.01

# %%
# create frequent itemsets
itemsets = apriori(df, min_support=0.01, use_colnames=True)
itemsets['length'] = itemsets['itemsets'].apply(lambda x: len(x))
itemsets
# Out:
#      support                                           itemsets  length
# 0   0.033013                                (Clothing Division)       1
# 1   0.393557                              (Housewares Division)       1
# 2   0.134854                              (Automotive Division)       1
# 3   0.467387                    (Personal Electronics Division)       1
# 4   0.046819                               (Computers Division)       1
# ..       ...                                                ...     ...
# 86  0.021809  (Jewelry Division, Automotive Division, Novelt...       5
# 87  0.019208  (Jewelry Division, Housewares Division, Automo...       5
# 88  0.038215  (Jewelry Division, Housewares Division, Novelt...       5
# 89  0.024010  (Jewelry Division, Automotive Division, Novelt...       5
# 90  0.017207  (Jewelry Division, Housewares Division, Automo...       6
#
# [91 rows x 3 columns]

# %%
itemsets[ (itemsets['length'] == 2) &
                   (itemsets['support'] >= 0.05) ]
# Out:
#      support                                           itemsets  length
# 13  0.067627         (Automotive Division, Housewares Division)       2
# 14  0.235494  (Personal Electronics Division, Housewares Div...       2
# 16  0.132853             (Garden Division, Housewares Division)       2
# 17  0.134854       (Housewares Division, Novelty Gift Division)       2
# 18  0.194878            (Jewelry Division, Housewares Division)       2
# 19  0.083033  (Personal Electronics Division, Automotive Div...       2
# 20  0.085434             (Automotive Division, Garden Division)       2
# 21  0.055622       (Automotive Division, Novelty Gift Division)       2
# 22  0.075230            (Automotive Division, Jewelry Division)       2
# 24  0.163265   (Personal Electronics Division, Garden Division)       2
# 25  0.169068  (Personal Electronics Division, Novelty Gift D...       2
# 26  0.197479  (Personal Electronics Division, Jewelry Division)       2
# 30  0.112245           (Garden Division, Novelty Gift Division)       2
# 31  0.127251                (Jewelry Division, Garden Division)       2
# 32  0.107243          (Jewelry Division, Novelty Gift Division)       2

# %%
itemsets[ (itemsets['length'] == 3) &
                   (itemsets['support'] >= 0.05) ]
# Out:
#      support                                           itemsets  length
# 37  0.050420  (Personal Electronics Division, Automotive Div...       3
# 42  0.098439  (Personal Electronics Division, Garden Divisio...       3
# 43  0.107843  (Personal Electronics Division, Housewares Div...       3
# 44  0.132053  (Personal Electronics Division, Jewelry Divisi...       3
# 48  0.068828  (Garden Division, Housewares Division, Novelty...       3
# 49  0.080232  (Jewelry Division, Garden Division, Housewares...       3
# 50  0.075430  (Jewelry Division, Housewares Division, Novelt...       3
# 51  0.058023  (Personal Electronics Division, Automotive Div...       3
# 53  0.051621  (Personal Electronics Division, Automotive Div...       3
# 60  0.087235  (Personal Electronics Division, Garden Divisio...       3
# 61  0.087835  (Personal Electronics Division, Jewelry Divisi...       3
# 62  0.085834  (Personal Electronics Division, Jewelry Divisi...       3
# 65  0.063025  (Jewelry Division, Garden Division, Novelty Gi...       3

# %%
# convert into rules
rules = association_rules(itemsets, metric='confidence', min_threshold=0.5)
rules["antecedents_length"] = rules["antecedents"].apply(lambda x: len(x))
rules["consequents_length"] = rules["consequents"].apply(lambda x: len(x))
print('Number of rules: ',len(rules))
# Out:
# Number of rules:  206

# %%
rules[rules['consequents_length']==1].sort_values(by=['lift'], ascending=False)
# Out:
#                                                                                        antecedents  \
# 187  (Personal Electronics Division, Jewelry Division, Novelty Gift Division, Automotive Division)
# 144                                 (Automotive Division, Novelty Gift Division, Jewelry Division)
# 132                    (Personal Electronics Division, Automotive Division, Novelty Gift Division)
# 173            (Jewelry Division, Housewares Division, Novelty Gift Division, Automotive Division)
# 59                                                    (Automotive Division, Novelty Gift Division)
# ..                                                                                             ...
# 3                                                                            (Automotive Division)
# 33                                                       (Housewares Division, Computers Division)
# 15                                                                              (Jewelry Division)
# 67                                                          (Jewelry Division, Computers Division)
# 12                                                                            (Computers Division)
#
#                          consequents  antecedent support  consequent support  \
# 187                (Garden Division)            0.029412            0.272109
# 144                (Garden Division)            0.034214            0.272109
# 132                (Garden Division)            0.044418            0.272109
# 173                (Garden Division)            0.024210            0.272109
# 59                 (Garden Division)            0.055622            0.272109
# ..                               ...                 ...                 ...
# 3              (Housewares Division)            0.134854            0.393557
# 33   (Personal Electronics Division)            0.031613            0.467387
# 15   (Personal Electronics Division)            0.356943            0.467387
# 67   (Personal Electronics Division)            0.029612            0.467387
# 12   (Personal Electronics Division)            0.046819            0.467387
#
#       support  confidence      lift  leverage  conviction  antecedents_length  \
# 187  0.024010    0.816327  3.000000  0.016006    3.962963                   4
# 144  0.027811    0.812865  2.987281  0.018501    3.889668                   3
# 132  0.035414    0.797297  2.930068  0.023328    3.590930                   3
# 173  0.019208    0.793388  2.915702  0.012620    3.522993                   4
# 59   0.044018    0.791367  2.908273  0.028882    3.488858                   2
# ..        ...         ...       ...       ...         ...                 ...
# 3    0.067627    0.501484  1.274233  0.014554    1.216495                   1
# 33   0.018207    0.575949  1.232275  0.003432    1.256013                   2
# 15   0.197479    0.553251  1.183711  0.030649    1.192198                   1
# 67   0.016206    0.547297  1.170973  0.002366    1.176518                   2
# 12   0.023409    0.500000  1.069777  0.001527    1.065226                   1
#
#      consequents_length
# 187                   1
# 144                   1
# 132                   1
# 173                   1
# 59                    1
# ..                  ...
# 3                     1
# 33                    1
# 15                    1
# 67                    1
# 12                    1
#
# [166 rows x 11 columns]

# %% [markdown]
# According to above table, the customers who bought (Personal Electronics Division, Jewelry Division, Novelty Gift Division, Automotive Division) is expected to buy (Garden Division) with a likelihood of 80% (confidence). Lift & conviction scores support that hypothesis too
# It would be better to keep them close to increase sales !

# %% [markdown]
# Customers who bought (Automotive Division) is expected to buy (Housewares Division) with a likelihood of 50% (confidence).

# %%
# print antecedents with length 2
rules[rules["antecedents_length"]==2]
# Out:
#                                             antecedents  \
# 17   (Clothing Division, Personal Electronics Division)
# 18             (Clothing Division, Housewares Division)
# 19           (Clothing Division, Novelty Gift Division)
# 20                (Clothing Division, Jewelry Division)
# 21             (Clothing Division, Housewares Division)
# ..                                                  ...
# 119            (Garden Division, Novelty Gift Division)
# 126           (Jewelry Division, Novelty Gift Division)
# 134        (Automotive Division, Novelty Gift Division)
# 141        (Automotive Division, Novelty Gift Division)
# 145        (Automotive Division, Novelty Gift Division)
#
#                                               consequents  antecedent support  \
# 17                                  (Housewares Division)            0.019808
# 18                        (Personal Electronics Division)            0.024010
# 19                                  (Housewares Division)            0.012805
# 20                                  (Housewares Division)            0.020008
# 21                                     (Jewelry Division)            0.024010
# ..                                                    ...                 ...
# 119  (Personal Electronics Division, Housewares Division)            0.112245
# 126  (Personal Electronics Division, Housewares Division)            0.107243
# 134      (Personal Electronics Division, Garden Division)            0.055622
# 141     (Personal Electronics Division, Jewelry Division)            0.055622
# 145                   (Jewelry Division, Garden Division)            0.055622
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 17             0.393557  0.016407    0.828283  2.104605  0.008611    3.531636
# 18             0.467387  0.016407    0.683333  1.462029  0.005185    1.681936
# 19             0.393557  0.010204    0.796875  2.024800  0.005165    2.985563
# 20             0.393557  0.016206    0.810000  2.058149  0.008332    3.191803
# 21             0.356943  0.016206    0.675000  1.891059  0.007636    1.978638
# ..                  ...       ...         ...       ...       ...         ...
# 119            0.235494  0.057623    0.513369  2.179964  0.031190    1.571017
# 126            0.235494  0.063625    0.593284  2.519313  0.038370    1.879702
# 134            0.163265  0.035414    0.636691  3.899730  0.026333    2.303092
# 141            0.197479  0.029412    0.528777  2.677637  0.018428    1.703060
# 145            0.127251  0.027811    0.500000  3.929245  0.020733    1.745498
#
#      antecedents_length  consequents_length
# 17                    2                   1
# 18                    2                   1
# 19                    2                   1
# 20                    2                   1
# 21                    2                   1
# ..                  ...                 ...
# 119                   2                   2
# 126                   2                   2
# 134                   2                   2
# 141                   2                   2
# 145                   2                   2
#
# [76 rows x 11 columns]

# %%
plt.scatter(rules['support'],rules['confidence'])
plt.xlabel('support')
plt.ylabel('confidence') 
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6))
sns.scatterplot(x = rules['support'], y = rules['confidence'], hue = rules['lift'], size = rules['lift'])
plt.title('Display of Support, Confidence and Lift values for Association Rules \n')

plt.show()

# %%
rules_1=rules[rules["antecedents"].str.contains("Personal Electronics Division", regex=False) & (rules["antecedents_length"] == 2)].sort_values("confidence", ascending=False).head(10)

# %%
fig, ax=plt.subplots(figsize=(15,10))
GA=nx.from_pandas_edgelist(rules_1,source='antecedents',target='consequents')
nx.draw(GA,with_labels=True)
plt.show()

# %% [markdown]
#  From above graph, we can clearly see that Personal Electronics Division along with automotive,and computer division corresponds to Jewelry Division, or Housewares Division

# %%
rules_1=rules[rules["antecedents"].str.contains("Automotive Division", regex=False) & (rules["antecedents_length"] == 1)].sort_values("confidence", ascending=False).head(10)
rules_1

# %%
# Out:
#               antecedents                      consequents  \
# 10  (Automotive Division)                (Garden Division)
# 9   (Automotive Division)  (Personal Electronics Division)
# 11  (Automotive Division)               (Jewelry Division)
# 3   (Automotive Division)            (Housewares Division)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 10            0.134854            0.272109  0.085434    0.633531  2.328227
# 9             0.134854            0.467387  0.083033    0.615727  1.317382
# 11            0.134854            0.356943  0.075230    0.557864  1.562893
# 3             0.134854            0.393557  0.067627    0.501484  1.274233
#
#     leverage  conviction  antecedents_length  consequents_length
# 10  0.048739    1.986229                   1                   1
# 9   0.020004    1.386028                   1                   1
# 11  0.027095    1.454431                   1                   1
# 3   0.014554    1.216495                   1                   1

# %%
fig, ax=plt.subplots(figsize=(15,10))
GA=nx.from_pandas_edgelist(rules_1,source='antecedents',target='consequents')
nx.draw(GA,with_labels=True)
plt.show()

# %% [markdown]
# Automotive Division is one which corresponds to other divisions, so a better option is to place Garden division catalog with 60% confidence and lift of 2.32, so it's more likely to catch the customer when automotive division product is being sold

# %%
rules_1=rules[rules["antecedents"].str.contains("Housewares Division", regex=False) & (rules["antecedents_length"] == 2)].sort_values("confidence", ascending=False).head(10)
rules_1
# Out:
#                                      antecedents  \
# 37  (Housewares Division, Novelty Gift Division)
# 25    (Automotive Division, Housewares Division)
# 35        (Garden Division, Housewares Division)
# 44     (Housewares Division, Computers Division)
# 18      (Clothing Division, Housewares Division)
# 40       (Jewelry Division, Housewares Division)
# 30    (Automotive Division, Housewares Division)
# 21      (Clothing Division, Housewares Division)
# 27    (Automotive Division, Housewares Division)
# 49        (Garden Division, Housewares Division)
#
#                         consequents  antecedent support  consequent support  \
# 37  (Personal Electronics Division)            0.134854            0.467387
# 25  (Personal Electronics Division)            0.067627            0.467387
# 35  (Personal Electronics Division)            0.132853            0.467387
# 44               (Jewelry Division)            0.031613            0.356943
# 18  (Personal Electronics Division)            0.024010            0.467387
# 40  (Personal Electronics Division)            0.194878            0.467387
# 30               (Jewelry Division)            0.067627            0.356943
# 21               (Jewelry Division)            0.024010            0.356943
# 27                (Garden Division)            0.067627            0.272109
# 49               (Jewelry Division)            0.132853            0.356943
#
#      support  confidence      lift  leverage  conviction  antecedents_length  \
# 37  0.107843    0.799703  1.711009  0.044814    2.659120                   2
# 25  0.050420    0.745562  1.595171  0.018812    2.093293                   2
# 35  0.098439    0.740964  1.585333  0.036346    2.056134                   2
# 44  0.021609    0.683544  1.914997  0.010325    2.032061                   2
# 18  0.016407    0.683333  1.462029  0.005185    1.681936                   2
# 40  0.132053    0.677618  1.449801  0.040969    1.652118                   2
# 30  0.045818    0.677515  1.898105  0.021679    1.994067                   2
# 21  0.016206    0.675000  1.891059  0.007636    1.978638                   2
# 27  0.045418    0.671598  2.468121  0.027016    2.216461                   2
# 49  0.080232    0.603916  1.691912  0.032811    1.623536                   2
#
#     consequents_length
# 37                   1
# 25                   1
# 35                   1
# 44                   1
# 18                   1
# 40                   1
# 30                   1
# 21                   1
# 27                   1
# 49                   1

# %%
fig, ax=plt.subplots(figsize=(15,10))
GA=nx.from_pandas_edgelist(rules_1,source='antecedents',target='consequents')
nx.draw(GA,with_labels=True)
plt.show()

# %% [markdown]
# Houseware Division, with other division corresponds to Personal Electronics Division, so placing Personal Electronics Division catalog in Houseware division item shipment will results in more sales of PED items.
#
# Same way, jewerly division sales can also be increased if placed in Housware Division shipment

# %%
rules_1=rules[(rules["antecedents_length"] == 2)].sort_values("confidence", ascending=False).head(10)
rules_1
# Out:
#                                             antecedents  \
# 65          (Novelty Gift Division, Computers Division)
# 42          (Novelty Gift Division, Computers Division)
# 17   (Clothing Division, Personal Electronics Division)
# 20                (Clothing Division, Jewelry Division)
# 74            (Jewelry Division, Novelty Gift Division)
# 37         (Housewares Division, Novelty Gift Division)
# 55         (Automotive Division, Novelty Gift Division)
# 19           (Clothing Division, Novelty Gift Division)
# 59         (Automotive Division, Novelty Gift Division)
# 32  (Personal Electronics Division, Computers Division)
#
#                         consequents  antecedent support  consequent support  \
# 65  (Personal Electronics Division)            0.014206            0.467387
# 42            (Housewares Division)            0.014206            0.393557
# 17            (Housewares Division)            0.019808            0.393557
# 20            (Housewares Division)            0.020008            0.393557
# 74  (Personal Electronics Division)            0.107243            0.467387
# 37  (Personal Electronics Division)            0.134854            0.467387
# 55  (Personal Electronics Division)            0.055622            0.467387
# 19            (Housewares Division)            0.012805            0.393557
# 59                (Garden Division)            0.055622            0.272109
# 32            (Housewares Division)            0.023409            0.393557
#
#      support  confidence      lift  leverage  conviction  antecedents_length  \
# 65  0.011805    0.830986  1.777940  0.005165    3.151294                   2
# 42  0.011805    0.830986  2.111473  0.006214    3.588119                   2
# 17  0.016407    0.828283  2.104605  0.008611    3.531636                   2
# 20  0.016206    0.810000  2.058149  0.008332    3.191803                   2
# 74  0.085834    0.800373  1.712442  0.035710    2.668043                   2
# 37  0.107843    0.799703  1.711009  0.044814    2.659120                   2
# 55  0.044418    0.798561  1.708565  0.018421    2.644043                   2
# 19  0.010204    0.796875  2.024800  0.005165    2.985563                   2
# 59  0.044018    0.791367  2.908273  0.028882    3.488858                   2
# 32  0.018207    0.777778  1.976275  0.008994    2.728992                   2
#
#     consequents_length
# 65                   1
# 42                   1
# 17                   1
# 20                   1
# 74                   1
# 37                   1
# 55                   1
# 19                   1
# 59                   1
# 32                   1

# %%
# High strength rules of Germany country having lift values >= 3 and confidence values >= 50 %
strong_rules = rules_1[(rules_1['lift'] >= 1.2) & (rules_1['confidence'] >= 0.6)]
strong_rules
# Out:
#                                             antecedents  \
# 65          (Novelty Gift Division, Computers Division)
# 42          (Novelty Gift Division, Computers Division)
# 17   (Clothing Division, Personal Electronics Division)
# 20                (Clothing Division, Jewelry Division)
# 74            (Jewelry Division, Novelty Gift Division)
# 37         (Housewares Division, Novelty Gift Division)
# 55         (Automotive Division, Novelty Gift Division)
# 19           (Clothing Division, Novelty Gift Division)
# 59         (Automotive Division, Novelty Gift Division)
# 32  (Personal Electronics Division, Computers Division)
#
#                         consequents  antecedent support  consequent support  \
# 65  (Personal Electronics Division)            0.014206            0.467387
# 42            (Housewares Division)            0.014206            0.393557
# 17            (Housewares Division)            0.019808            0.393557
# 20            (Housewares Division)            0.020008            0.393557
# 74  (Personal Electronics Division)            0.107243            0.467387
# 37  (Personal Electronics Division)            0.134854            0.467387
# 55  (Personal Electronics Division)            0.055622            0.467387
# 19            (Housewares Division)            0.012805            0.393557
# 59                (Garden Division)            0.055622            0.272109
# 32            (Housewares Division)            0.023409            0.393557
#
#      support  confidence      lift  leverage  conviction  antecedents_length  \
# 65  0.011805    0.830986  1.777940  0.005165    3.151294                   2
# 42  0.011805    0.830986  2.111473  0.006214    3.588119                   2
# 17  0.016407    0.828283  2.104605  0.008611    3.531636                   2
# 20  0.016206    0.810000  2.058149  0.008332    3.191803                   2
# 74  0.085834    0.800373  1.712442  0.035710    2.668043                   2
# 37  0.107843    0.799703  1.711009  0.044814    2.659120                   2
# 55  0.044418    0.798561  1.708565  0.018421    2.644043                   2
# 19  0.010204    0.796875  2.024800  0.005165    2.985563                   2
# 59  0.044018    0.791367  2.908273  0.028882    3.488858                   2
# 32  0.018207    0.777778  1.976275  0.008994    2.728992                   2
#
#     consequents_length
# 65                   1
# 42                   1
# 17                   1
# 20                   1
# 74                   1
# 37                   1
# 55                   1
# 19                   1
# 59                   1
# 32                   1

# %%
pivot2 = strong_rules.pivot(index = 'antecedents', columns = 'consequents', values = 'lift')
fig, ax = plt.subplots(figsize=(10,6))
sns.heatmap(pivot2, annot = True, fmt = '.2f', linewidths = 2, linecolor = 'black', cmap = 'jet')
plt.title('Association Rules strength\n')
plt.show()

# %% [markdown]
# Rules strength are the key to increase the sales of catalog.
# We can use popularity of one item to increase sales of other items.

# %% [markdown]
# Here Personal Electronics Division catalog can be send with Novelty Gift, Computers, Jewelry and Housewares Divisions.
#
# Same way garden division can be send with Automotive division and Novelty Gift Division shipments/email with a lift of 2.91.

# %% [markdown]
# # Association with min support 0.05

# %%
# create frequent itemsets
itemsets = apriori(df, min_support=0.05, use_colnames=True)

# %%
# convert into rules
rules = association_rules(itemsets, metric='confidence', min_threshold=0.5)
rules["antecedents_length"] = rules["antecedents"].apply(lambda x: len(x))
rules["consequents_length"] = rules["consequents"].apply(lambda x: len(x))
print('Number of rules: ',len(rules))
# Out:
# Number of rules:  56

# %%
rules.sort_values(by=['lift'], ascending=False)
# Out:
#                                                                     antecedents  \
# 52           (Personal Electronics Division, Jewelry Division, Garden Division)
# 40        (Personal Electronics Division, Garden Division, Housewares Division)
# 27                         (Personal Electronics Division, Automotive Division)
# 51                                    (Jewelry Division, Novelty Gift Division)
# 31                             (Personal Electronics Division, Garden Division)
# 6                                                         (Automotive Division)
# 53     (Personal Electronics Division, Jewelry Division, Novelty Gift Division)
# 20                                       (Garden Division, Housewares Division)
# 44                                     (Garden Division, Novelty Gift Division)
# 38                                    (Jewelry Division, Novelty Gift Division)
# 42  (Personal Electronics Division, Housewares Division, Novelty Gift Division)
# 32                       (Personal Electronics Division, Novelty Gift Division)
# 48     (Personal Electronics Division, Jewelry Division, Novelty Gift Division)
# 22                                 (Housewares Division, Novelty Gift Division)
# 45           (Personal Electronics Division, Jewelry Division, Garden Division)
# 55                   (Jewelry Division, Garden Division, Novelty Gift Division)
# 50               (Jewelry Division, Housewares Division, Novelty Gift Division)
# 43                (Garden Division, Housewares Division, Novelty Gift Division)
# 46        (Personal Electronics Division, Garden Division, Housewares Division)
# 25                                    (Jewelry Division, Novelty Gift Division)
# 29                         (Personal Electronics Division, Automotive Division)
# 37                                    (Jewelry Division, Novelty Gift Division)
# 16                                 (Housewares Division, Novelty Gift Division)
# 54      (Personal Electronics Division, Garden Division, Novelty Gift Division)
# 17                            (Personal Electronics Division, Jewelry Division)
# 24                                       (Garden Division, Housewares Division)
# 41      (Personal Electronics Division, Garden Division, Novelty Gift Division)
# 47                     (Jewelry Division, Garden Division, Housewares Division)
# 33                                     (Garden Division, Novelty Gift Division)
# 49  (Personal Electronics Division, Housewares Division, Novelty Gift Division)
# 15                       (Personal Electronics Division, Novelty Gift Division)
# 23                                          (Jewelry Division, Garden Division)
# 12                                   (Automotive Division, Housewares Division)
# 9                                                       (Novelty Gift Division)
# 14                                       (Garden Division, Housewares Division)
# 39                                     (Garden Division, Novelty Gift Division)
# 18                         (Personal Electronics Division, Housewares Division)
# 26                                 (Housewares Division, Novelty Gift Division)
# 7                                                         (Automotive Division)
# 21                                     (Garden Division, Novelty Gift Division)
# 11                         (Personal Electronics Division, Automotive Division)
# 13                             (Personal Electronics Division, Garden Division)
# 34                             (Personal Electronics Division, Garden Division)
# 3                                                       (Novelty Gift Division)
# 35                                          (Jewelry Division, Garden Division)
# 30                                      (Automotive Division, Jewelry Division)
# 28                                       (Automotive Division, Garden Division)
# 19                                      (Jewelry Division, Housewares Division)
# 36                       (Personal Electronics Division, Novelty Gift Division)
# 4                                                            (Jewelry Division)
# 5                                                         (Automotive Division)
# 8                                                             (Garden Division)
# 1                                               (Personal Electronics Division)
# 2                                                         (Housewares Division)
# 0                                                         (Automotive Division)
# 10                                                           (Jewelry Division)
#
#                                              consequents  antecedent support  \
# 52                               (Novelty Gift Division)            0.087835
# 40                               (Novelty Gift Division)            0.098439
# 27                                     (Garden Division)            0.083033
# 51  (Personal Electronics Division, Housewares Division)            0.107243
# 31                               (Novelty Gift Division)            0.163265
# 6                                      (Garden Division)            0.134854
# 53                                     (Garden Division)            0.085834
# 20                               (Novelty Gift Division)            0.132853
# 44  (Personal Electronics Division, Housewares Division)            0.112245
# 38                                     (Garden Division)            0.107243
# 42                                     (Garden Division)            0.107843
# 32                                     (Garden Division)            0.169068
# 48                                 (Housewares Division)            0.085834
# 22                                     (Garden Division)            0.134854
# 45                                 (Housewares Division)            0.087835
# 55                       (Personal Electronics Division)            0.063025
# 50                       (Personal Electronics Division)            0.075430
# 43                       (Personal Electronics Division)            0.068828
# 46                                    (Jewelry Division)            0.098439
# 25                                 (Housewares Division)            0.107243
# 29                                    (Jewelry Division)            0.083033
# 37                       (Personal Electronics Division)            0.107243
# 16                       (Personal Electronics Division)            0.134854
# 54                                    (Jewelry Division)            0.087235
# 17                                 (Housewares Division)            0.197479
# 24                                    (Jewelry Division)            0.132853
# 41                                 (Housewares Division)            0.087235
# 47                       (Personal Electronics Division)            0.080232
# 33                       (Personal Electronics Division)            0.112245
# 49                                    (Jewelry Division)            0.107843
# 15                                 (Housewares Division)            0.169068
# 23                                 (Housewares Division)            0.127251
# 12                       (Personal Electronics Division)            0.067627
# 9                        (Personal Electronics Division)            0.227491
# 14                       (Personal Electronics Division)            0.132853
# 39                                    (Jewelry Division)            0.112245
# 18                                    (Jewelry Division)            0.235494
# 26                                    (Jewelry Division)            0.134854
# 7                                     (Jewelry Division)            0.134854
# 21                                 (Housewares Division)            0.112245
# 11                                 (Housewares Division)            0.083033
# 13                                 (Housewares Division)            0.163265
# 34                                    (Jewelry Division)            0.163265
# 3                                  (Housewares Division)            0.227491
# 35                       (Personal Electronics Division)            0.127251
# 30                       (Personal Electronics Division)            0.075230
# 28                       (Personal Electronics Division)            0.085434
# 19                       (Personal Electronics Division)            0.194878
# 36                                    (Jewelry Division)            0.169068
# 4                                  (Housewares Division)            0.356943
# 5                        (Personal Electronics Division)            0.134854
# 8                        (Personal Electronics Division)            0.272109
# 1                                  (Housewares Division)            0.467387
# 2                        (Personal Electronics Division)            0.393557
# 0                                  (Housewares Division)            0.134854
# 10                       (Personal Electronics Division)            0.356943
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 52            0.227491  0.053221    0.605923  2.663501  0.033240    1.960297
# 40            0.227491  0.057623    0.585366  2.573139  0.035229    1.863110
# 27            0.272109  0.058023    0.698795  2.568072  0.035429    2.416599
# 51            0.235494  0.063625    0.593284  2.519313  0.038370    1.879702
# 31            0.227491  0.087235    0.534314  2.348725  0.050094    1.658861
# 6             0.272109  0.085434    0.633531  2.328227  0.048739    1.986229
# 53            0.272109  0.053221    0.620047  2.278671  0.029865    1.915738
# 20            0.227491  0.068828    0.518072  2.277331  0.038605    1.602956
# 44            0.235494  0.057623    0.513369  2.179964  0.031190    1.571017
# 38            0.272109  0.063025    0.587687  2.159748  0.033843    1.765383
# 42            0.272109  0.057623    0.534323  1.963636  0.028278    1.563081
# 32            0.272109  0.087235    0.515976  1.896213  0.041230    1.503834
# 48            0.393557  0.063625    0.741259  1.883483  0.029845    2.343819
# 22            0.272109  0.068828    0.510386  1.875668  0.032133    1.486663
# 45            0.393557  0.062825    0.715262  1.817427  0.028257    2.129826
# 55            0.467387  0.053221    0.844444  1.806735  0.023764    3.423941
# 50            0.467387  0.063625    0.843501  1.804717  0.028370    3.403307
# 43            0.467387  0.057623    0.837209  1.791255  0.025454    3.271766
# 46            0.356943  0.062825    0.638211  1.787994  0.027688    1.777439
# 25            0.393557  0.075430    0.703358  1.787181  0.033224    2.044360
# 29            0.356943  0.051621    0.621687  1.741699  0.021983    1.699801
# 37            0.467387  0.085834    0.800373  1.712442  0.035710    2.668043
# 16            0.467387  0.107843    0.799703  1.711009  0.044814    2.659120
# 54            0.356943  0.053221    0.610092  1.709214  0.022083    1.649253
# 17            0.393557  0.132053    0.668693  1.699099  0.054333    1.830455
# 24            0.356943  0.080232    0.603916  1.691912  0.032811    1.623536
# 41            0.393557  0.057623    0.660550  1.678409  0.023291    1.786547
# 47            0.467387  0.062825    0.783042  1.675362  0.025326    2.454918
# 33            0.467387  0.087235    0.777184  1.662827  0.034773    2.390367
# 49            0.356943  0.063625    0.589981  1.652874  0.025132    1.568361
# 15            0.393557  0.107843    0.637870  1.620780  0.041305    1.674654
# 23            0.393557  0.080232    0.630503  1.602061  0.030152    1.641266
# 12            0.467387  0.050420    0.745562  1.595171  0.018812    2.093293
# 9             0.467387  0.169068    0.743184  1.590082  0.062741    2.073908
# 14            0.467387  0.098439    0.740964  1.585333  0.036346    2.056134
# 39            0.356943  0.063025    0.561497  1.573074  0.022960    1.466484
# 18            0.356943  0.132053    0.560748  1.570974  0.047995    1.463981
# 26            0.356943  0.075430    0.559347  1.567050  0.027295    1.459329
# 7             0.356943  0.075230    0.557864  1.562893  0.027095    1.454431
# 21            0.393557  0.068828    0.613191  1.558072  0.024653    1.567808
# 11            0.393557  0.050420    0.607229  1.542923  0.017742    1.544010
# 13            0.393557  0.098439    0.602941  1.532028  0.034185    1.527337
# 34            0.356943  0.087835    0.537990  1.507217  0.029559    1.391869
# 3             0.393557  0.134854    0.592788  1.506230  0.045323    1.489255
# 35            0.467387  0.087835    0.690252  1.476831  0.028360    1.719502
# 30            0.467387  0.051621    0.686170  1.468099  0.016459    1.697140
# 28            0.467387  0.058023    0.679157  1.453093  0.018092    1.660042
# 19            0.467387  0.132053    0.677618  1.449801  0.040969    1.652118
# 36            0.356943  0.085834    0.507692  1.422335  0.025487    1.306210
# 4             0.393557  0.194878    0.545964  1.387254  0.054400    1.335671
# 5             0.467387  0.083033    0.615727  1.317382  0.020004    1.386028
# 8             0.467387  0.163265    0.600000  1.283733  0.036085    1.331533
# 1             0.393557  0.235494    0.503853  1.280252  0.051551    1.222304
# 2             0.467387  0.235494    0.598373  1.280252  0.051551    1.326139
# 0             0.393557  0.067627    0.501484  1.274233  0.014554    1.216495
# 10            0.467387  0.197479    0.553251  1.183711  0.030649    1.192198
#
#     antecedents_length  consequents_length
# 52                   3                   1
# 40                   3                   1
# 27                   2                   1
# 51                   2                   2
# 31                   2                   1
# 6                    1                   1
# 53                   3                   1
# 20                   2                   1
# 44                   2                   2
# 38                   2                   1
# 42                   3                   1
# 32                   2                   1
# 48                   3                   1
# 22                   2                   1
# 45                   3                   1
# 55                   3                   1
# 50                   3                   1
# 43                   3                   1
# 46                   3                   1
# 25                   2                   1
# 29                   2                   1
# 37                   2                   1
# 16                   2                   1
# 54                   3                   1
# 17                   2                   1
# 24                   2                   1
# 41                   3                   1
# 47                   3                   1
# 33                   2                   1
# 49                   3                   1
# 15                   2                   1
# 23                   2                   1
# 12                   2                   1
# 9                    1                   1
# 14                   2                   1
# 39                   2                   1
# 18                   2                   1
# 26                   2                   1
# 7                    1                   1
# 21                   2                   1
# 11                   2                   1
# 13                   2                   1
# 34                   2                   1
# 3                    1                   1
# 35                   2                   1
# 30                   2                   1
# 28                   2                   1
# 19                   2                   1
# 36                   2                   1
# 4                    1                   1
# 5                    1                   1
# 8                    1                   1
# 1                    1                   1
# 2                    1                   1
# 0                    1                   1
# 10                   1                   1

# %%
fig, ax = plt.subplots(figsize=(8,5))
sns.scatterplot(x = rules['support'], y = rules['confidence'], hue = rules['lift'], size = rules['lift'])
plt.title('Display of Support, Confidence and Lift values for Association Rules \n')

plt.show()

# %%
rules_1=rules[(rules["antecedents_length"] == 1)].sort_values("confidence", ascending=False).head(10)
rules_1
# Out:
#                         antecedents                      consequents  \
# 9           (Novelty Gift Division)  (Personal Electronics Division)
# 6             (Automotive Division)                (Garden Division)
# 5             (Automotive Division)  (Personal Electronics Division)
# 8                 (Garden Division)  (Personal Electronics Division)
# 2             (Housewares Division)  (Personal Electronics Division)
# 3           (Novelty Gift Division)            (Housewares Division)
# 7             (Automotive Division)               (Jewelry Division)
# 10               (Jewelry Division)  (Personal Electronics Division)
# 4                (Jewelry Division)            (Housewares Division)
# 1   (Personal Electronics Division)            (Housewares Division)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 9             0.227491            0.467387  0.169068    0.743184  1.590082
# 6             0.134854            0.272109  0.085434    0.633531  2.328227
# 5             0.134854            0.467387  0.083033    0.615727  1.317382
# 8             0.272109            0.467387  0.163265    0.600000  1.283733
# 2             0.393557            0.467387  0.235494    0.598373  1.280252
# 3             0.227491            0.393557  0.134854    0.592788  1.506230
# 7             0.134854            0.356943  0.075230    0.557864  1.562893
# 10            0.356943            0.467387  0.197479    0.553251  1.183711
# 4             0.356943            0.393557  0.194878    0.545964  1.387254
# 1             0.467387            0.393557  0.235494    0.503853  1.280252
#
#     leverage  conviction  antecedents_length  consequents_length
# 9   0.062741    2.073908                   1                   1
# 6   0.048739    1.986229                   1                   1
# 5   0.020004    1.386028                   1                   1
# 8   0.036085    1.331533                   1                   1
# 2   0.051551    1.326139                   1                   1
# 3   0.045323    1.489255                   1                   1
# 7   0.027095    1.454431                   1                   1
# 10  0.030649    1.192198                   1                   1
# 4   0.054400    1.335671                   1                   1
# 1   0.051551    1.222304                   1                   1

# %%
fig, ax=plt.subplots(figsize=(15,10))
GA=nx.from_pandas_edgelist(rules_1,source='antecedents',target='consequents')
nx.draw(GA,with_labels=True)
plt.show()

# %% [markdown]
# __This graph perfectly explains of the catalog should go with which type of shipment, with a decent lift and confidence above 50%__

# %%
rules_1=rules[(rules["antecedents_length"] == 2)].sort_values("confidence", ascending=False).head(10)
rules_1
# Out:
#                                              antecedents  \
# 37             (Jewelry Division, Novelty Gift Division)
# 16          (Housewares Division, Novelty Gift Division)
# 33              (Garden Division, Novelty Gift Division)
# 12            (Automotive Division, Housewares Division)
# 14                (Garden Division, Housewares Division)
# 25             (Jewelry Division, Novelty Gift Division)
# 27  (Personal Electronics Division, Automotive Division)
# 35                   (Jewelry Division, Garden Division)
# 30               (Automotive Division, Jewelry Division)
# 28                (Automotive Division, Garden Division)
#
#                         consequents  antecedent support  consequent support  \
# 37  (Personal Electronics Division)            0.107243            0.467387
# 16  (Personal Electronics Division)            0.134854            0.467387
# 33  (Personal Electronics Division)            0.112245            0.467387
# 12  (Personal Electronics Division)            0.067627            0.467387
# 14  (Personal Electronics Division)            0.132853            0.467387
# 25            (Housewares Division)            0.107243            0.393557
# 27                (Garden Division)            0.083033            0.272109
# 35  (Personal Electronics Division)            0.127251            0.467387
# 30  (Personal Electronics Division)            0.075230            0.467387
# 28  (Personal Electronics Division)            0.085434            0.467387
#
#      support  confidence      lift  leverage  conviction  antecedents_length  \
# 37  0.085834    0.800373  1.712442  0.035710    2.668043                   2
# 16  0.107843    0.799703  1.711009  0.044814    2.659120                   2
# 33  0.087235    0.777184  1.662827  0.034773    2.390367                   2
# 12  0.050420    0.745562  1.595171  0.018812    2.093293                   2
# 14  0.098439    0.740964  1.585333  0.036346    2.056134                   2
# 25  0.075430    0.703358  1.787181  0.033224    2.044360                   2
# 27  0.058023    0.698795  2.568072  0.035429    2.416599                   2
# 35  0.087835    0.690252  1.476831  0.028360    1.719502                   2
# 30  0.051621    0.686170  1.468099  0.016459    1.697140                   2
# 28  0.058023    0.679157  1.453093  0.018092    1.660042                   2
#
#     consequents_length
# 37                   1
# 16                   1
# 33                   1
# 12                   1
# 14                   1
# 25                   1
# 27                   1
# 35                   1
# 30                   1
# 28                   1

# %%
# High strength rules of Germany country having lift values >= 3 and confidence values >= 50 %
strong_rules = rules_1[(rules['lift'] >= 1.5) & (rules_1['confidence'] >= 0.6)]

# %%
pivot2 = strong_rules.pivot(index = 'antecedents', columns = 'consequents', values = 'lift')
fig, ax = plt.subplots(figsize=(10,6))
sns.heatmap(pivot2, annot = True, fmt = '.2f', linewidths = 2, linecolor = 'black', cmap = 'jet')
plt.title('Association Rules strength\n')
plt.show()

# %% [markdown]
# This shows the Garden division catalog can be send with Personal Division and Automotive division shipments,with a lift of 2.57 for a sell being made.
#
# Houseware division can go with Jewelry Division and Novelty Gift Division.

# %%
df.columns
# Out:
# Index(['Clothing Division', 'Housewares Division', 'Automotive Division',
#        'Personal Electronics Division', 'Computers Division',
#        'Garden Division', 'Novelty Gift Division', 'Jewelry Division'],
#       dtype='object')

# %%
len(df[(df['Automotive Division']==1)])
# Out:
# 674

# %%
len(df[(df['Garden Division']==1)])
# Out:
# 1360

# %% [markdown]
# # Association with min_support 0.1

# %%
# create frequent itemsets
itemsets = apriori(df, min_support=0.1, use_colnames=True)
# convert into rules
rules = association_rules(itemsets, metric='confidence', min_threshold=0.5)
print('Number of rules: ',len(rules))
# Out:
# Number of rules:  12

# %%
rules.sort_values(by=['lift'], ascending=False)
# Out:
#                                           antecedents  \
# 8        (Housewares Division, Novelty Gift Division)
# 9   (Personal Electronics Division, Jewelry Division)
# 7   (Personal Electronics Division, Novelty Gift D...
# 5                             (Novelty Gift Division)
# 10  (Personal Electronics Division, Housewares Div...
# 2                             (Novelty Gift Division)
# 11            (Jewelry Division, Housewares Division)
# 3                                  (Jewelry Division)
# 4                                   (Garden Division)
# 0                     (Personal Electronics Division)
# 1                               (Housewares Division)
# 6                                  (Jewelry Division)
#
#                         consequents  antecedent support  consequent support  \
# 8   (Personal Electronics Division)            0.134854            0.467387
# 9             (Housewares Division)            0.197479            0.393557
# 7             (Housewares Division)            0.169068            0.393557
# 5   (Personal Electronics Division)            0.227491            0.467387
# 10               (Jewelry Division)            0.235494            0.356943
# 2             (Housewares Division)            0.227491            0.393557
# 11  (Personal Electronics Division)            0.194878            0.467387
# 3             (Housewares Division)            0.356943            0.393557
# 4   (Personal Electronics Division)            0.272109            0.467387
# 0             (Housewares Division)            0.467387            0.393557
# 1   (Personal Electronics Division)            0.393557            0.467387
# 6   (Personal Electronics Division)            0.356943            0.467387
#
#      support  confidence      lift  leverage  conviction
# 8   0.107843    0.799703  1.711009  0.044814    2.659120
# 9   0.132053    0.668693  1.699099  0.054333    1.830455
# 7   0.107843    0.637870  1.620780  0.041305    1.674654
# 5   0.169068    0.743184  1.590082  0.062741    2.073908
# 10  0.132053    0.560748  1.570974  0.047995    1.463981
# 2   0.134854    0.592788  1.506230  0.045323    1.489255
# 11  0.132053    0.677618  1.449801  0.040969    1.652118
# 3   0.194878    0.545964  1.387254  0.054400    1.335671
# 4   0.163265    0.600000  1.283733  0.036085    1.331533
# 0   0.235494    0.503853  1.280252  0.051551    1.222304
# 1   0.235494    0.598373  1.280252  0.051551    1.326139
# 6   0.197479    0.553251  1.183711  0.030649    1.192198

# %%
fig, ax = plt.subplots(figsize=(8,5))
sns.scatterplot(x = rules['support'], y = rules['confidence'], hue = rules['lift'], size = rules['lift'])
plt.title('Display of Support, Confidence and Lift values for Association Rules \n')

plt.show()

# %%
pivot2 = rules.pivot(index = 'antecedents', columns = 'consequents', values = 'lift')
fig, ax = plt.subplots(figsize=(10,6))
sns.heatmap(pivot2, annot = True, fmt = '.2f', linewidths = 2, linecolor = 'black', cmap = 'jet')
plt.title('Association Rules strength\n')
plt.show()

# %%
fig, ax=plt.subplots(figsize=(10,10))
GA=nx.from_pandas_edgelist(rules,source='antecedents',target='consequents')
nx.draw(GA,with_labels=True)
plt.show()

# %% [markdown]
# __Personal Electronics Division  and Housewares Division are common with any other catalog__
